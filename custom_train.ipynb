# %%
# Installing Ultralytics
# leverages the primitive yolov8 model
# !pip install ultralytics

# %%
# Import Dependancy
import ultralytics
ultralytics.checks()

# %%
# Library Imports
import os
import shutil
import random

# Import to add clear progress bars 
# !pip install tqdm --upgrade
from tqdm.notebook import tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.4)

# %%
# Set Path for images and labels
train_path_img = "your_path"
train_path_label = "your_path"
val_path_img = "your_path"
val_path_label = "your_path"

# %%
"""
    Set the directory as given in the "file_directory_structure.txt" file
"""

# %%
# CLI based training approach
"""
    task: detect (perform object detections)
    mode: train (set to learn from the data provided)
    model: yolov8s.t (model architecture to be imported)
    data: <path_to_yaml_file> (path to the yaml file that has data and classes)
    epochs: 100 (minimum of 100, maximum of 300)
    imgsz: 416 (416 x 416 for increased computational efficiency)
    batch: 6 (no of images to be trained at once at a time)
    project: <path_to_training_results>
    name: RT-Traffic-Analytics
"""
# !yolo task=detect mode=train model=yolov8s.pt data=/content/yolo_data/dataset.yaml epochs=100 imgsz=416 batch=6 project=/content/yolo_data/training_results name=trafficanalysis
# Out:
# Ultralytics YOLOv8.2.67 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/yolo_data/dataset.yaml, epochs=100, time=None, patience=100, batch=6, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/yolo_data/training_results, name=trafficanalysis2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=/content/yolo_data/training_results/trafficanalysis2
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117983  ultralytics.nn.modules.head.Detect           [5, [128, 256, 512]]
# Model summary: 225 layers, 11,137,535 parameters, 11,137,519 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /content/yolo_data/training_results/trafficanalysis2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/yolo_data/labels/train.cache... 24 images, 6 backgrounds, 0 corrupt: 100% 30/30 [00:00<?, ?it/s]
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.12 (you have 1.4.11). Upgrade using: pip install --upgrade albumentations
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /content/yolo_data/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<?, ?it/s]
# Plotting labels to /content/yolo_data/training_results/trafficanalysis2/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001111, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.000515625), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to /content/yolo_data/training_results/trafficanalysis2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      1.09G      1.926      4.116      1.468         85        416: 100% 5/5 [00:03<00:00,  1.26it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.01s/it]
#                    all          4         41     0.0589      0.672     0.0917     0.0587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      1.06G      1.816      3.421      1.432         28        416: 100% 5/5 [00:00<00:00,  8.86it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 19.70it/s]
#                    all          4         41      0.355      0.228      0.231      0.152
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      1.06G      1.757      2.309      1.381         90        416: 100% 5/5 [00:00<00:00,  9.52it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 19.22it/s]
#                    all          4         41       0.15      0.498      0.295      0.195
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100     0.958G      1.726      1.824      1.364         78        416: 100% 5/5 [00:00<00:00, 10.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 20.27it/s]
#                    all          4         41      0.465      0.443      0.398      0.251
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100     0.954G      1.745      1.849      1.406         60        416: 100% 5/5 [00:00<00:00,  9.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 11.80it/s]
#                    all          4         41      0.332      0.498      0.388      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      1.06G      1.659      1.542      1.274         79        416: 100% 5/5 [00:00<00:00,  7.08it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 10.35it/s]
#                    all          4         41      0.327      0.546      0.463      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100     0.954G      1.593      1.511      1.218         74        416: 100% 5/5 [00:00<00:00,  5.99it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  6.33it/s]
#                    all          4         41      0.569      0.582      0.567      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100     0.954G      1.593      1.525      1.246         71        416: 100% 5/5 [00:00<00:00,  5.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  6.44it/s]
#                    all          4         41      0.678      0.556      0.671      0.367
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100     0.954G      1.503       1.49      1.207         73        416: 100% 5/5 [00:00<00:00, 10.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 20.83it/s]
#                    all          4         41       0.66      0.583      0.649      0.402
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100     0.954G      1.552       1.43      1.226        103        416: 100% 5/5 [00:00<00:00, 10.51it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 15.38it/s]
#                    all          4         41        0.7      0.593      0.675      0.424
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100     0.954G      1.485      1.325      1.209         55        416: 100% 5/5 [00:00<00:00, 10.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 21.37it/s]
#                    all          4         41      0.807      0.613      0.787      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100     0.956G      1.443      1.239      1.204         99        416: 100% 5/5 [00:00<00:00, 10.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 19.16it/s]
#                    all          4         41      0.768      0.664      0.761      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      1.06G      1.539      1.404      1.279         75        416: 100% 5/5 [00:00<00:00, 10.89it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 18.74it/s]
#                    all          4         41      0.768      0.664      0.761      0.439
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100     0.977G       1.57      1.255      1.227         67        416: 100% 5/5 [00:00<00:00, 10.42it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 20.47it/s]
#                    all          4         41      0.614      0.703      0.677      0.376
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100     0.954G      1.514      1.273      1.211         73        416: 100% 5/5 [00:00<00:00,  9.96it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 21.87it/s]
#                    all          4         41      0.388      0.682      0.493      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      1.06G      1.451      1.266      1.212         45        416: 100% 5/5 [00:00<00:00,  7.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 10
85it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 19.25it/s]
#                    all          4         41      0.679      0.668      0.769      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100     0.958G     0.9463     0.6512     0.9823         35        416: 100% 5/5 [00:00<00:00, 11.13it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 22.10it/s]
#                    all          4         41      0.679      0.668      0.769      0.438
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100     0.958G     0.9045     0.6427     0.9691         48        416: 100% 5/5 [00:00<00:00, 11.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 21.50it/s]
#                    all          4         41      0.612      0.941       0.81      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100     0.958G     0.9119     0.6189     0.9656         45        416: 100% 5/5 [00:00<00:00, 11.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 20.41it/s]
#                    all          4         41      0.612      0.941       0.81      0.453
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100     0.958G     0.9855     0.6338      1.022         34        416: 100% 5/5 [00:00<00:00,  8.45it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 11.09it/s]
#                    all          4         41       0.61      0.933       0.81      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100     0.958G      0.878      0.623     0.9559         36        416: 100% 5/5 [00:00<00:00,  7.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 23.46it/s]
#                    all          4         41       0.61      0.933       0.81      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100     0.958G     0.9432     0.6088     0.9863         50        416: 100% 5/5 [00:00<00:00,  6.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 14.22it/s]
#                    all          4         41      0.606      0.901      0.809      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      1.07G     0.8136     0.5324       0.92         39        416: 100% 5/5 [00:00<00:00,  6.49it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  9.40it/s]
#                    all          4         41      0.606      0.901      0.809      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100     0.958G     0.8816     0.6015     0.9733         47        416: 100% 5/5 [00:00<00:00,  6.59it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 12.02it/s]
#                    all          4         41      0.606      0.901      0.809      0.458
#
# 100 epochs completed in 0.048 hours.
# Optimizer stripped from /content/yolo_data/training_results/trafficanalysis2/weights/last.pt, 22.5MB
# Optimizer stripped from /content/yolo_data/training_results/trafficanalysis2/weights/best.pt, 22.5MB
#
# Validating /content/yolo_data/training_results/trafficanalysis2/weights/best.pt...
# Ultralytics YOLOv8.2.67 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00, 20.63it/s]
#                    all          4         41      0.765      0.821      0.831      0.546
#                    car          4         12      0.916       0.91      0.939      0.664
#                    bus          3          4       0.47       0.75      0.623      0.424
#            two-wheeler          4          9      0.762      0.778      0.712      0.306
#          heavy-vehicle          2          3      0.762      0.667      0.913      0.838
#          auto-rickshaw          3         13      0.914          1      0.968        0.5
# Speed: 0.1ms preprocess, 3.2ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to /content/yolo_data/training_results/trafficanalysis2
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
"""
    Model Stats:
        Model description: Ultralytics YOLOv8.2.67
        Python version: Python-3.10.12
        Torch and CUDA version: torch-2.3.1+cu121
        Device trained on: CUDA:0 (Tesla T4, 15102MiB) - Tesla T4 GPU with 15.835 Gb Memory
        No of layers: 168 layers
        No of parameters: 11,127,519 parameters
        No of gradients to optimize: 11,137,535
        No of GFLOPs - 28.4 (Represents computational complexity - performs 28.4 billion floating-point operations per second)
    
    Trained Model Stats:
        Generic Performance Evaluation:
            Overall Prediction Accuracy - 0.765
            Recall of bounding boxes - 0.821
        Class Wise Performance Evaluation:
            Precision indicates how many of the detected objects were actually correct.
            Recall indicates how well the model can find the relevant objects in a frame
            <class>: <precision,recall>
            car: <0.91,0.91>
            bus: <0.47,0.75>
            two-wheeler: <0.76,0.78>
            heavy-vehicle: <0.76,0.67>
            auto-rickshaw: <0.91,1.0>
            
    Model Inference Stats:
        Avg time to preprocess: 0.1ms
        Avg time to inference: 3.2ms
        Avg time to postprocess: 1.1ms 
"""

# %%
# Inference using the Trained Model
"""
    task: detect (inference using the model)
    mode: predict 
    model: <path_to_weights_file>
    conf: 0.5 (confidence score for prediction)
    source: <path_to_test_image>
    
"""
# !yolo task=detect mode=predict model=/content/yolo_data/training_results/trafficanalysis/weights/best.pt conf=0.5 source=/content/30.png
# Out:
# Ultralytics YOLOv8.2.67 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/30.png: 256x416 3 cars, 1 heavy-vehicle, 5 auto-rickshaws, 99.7ms
# Speed: 2.2ms preprocess, 99.7ms inference, 899.0ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
