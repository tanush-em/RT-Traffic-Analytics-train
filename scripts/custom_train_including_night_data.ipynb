# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Installing Ultralytics
# leverages the primitive yolov8 model
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
# Import Dependancy
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.6/78.2 GB disk)

# %%
# Library Imports
import os
import shutil
import random

# Import to add clear progress bars
# !pip install tqdm --upgrade
from tqdm.notebook import tqdm

# %%
# Set Path for images and labels
train_path_img = "/content/drive/MyDrive/RT-Traffic-Analytics-train/data/train/images"
train_path_label = "/content/drive/MyDrive/RT-Traffic-Analytics-train/data/train/labels"
val_path_img = "/content/drive/MyDrive/RT-Traffic-Analytics-train/data/val/images"
val_path_label = "/content/drive/MyDrive/RT-Traffic-Analytics-train/data/val/labels"

# %%
"""
    Set the directory as given in the "file_directory_structure.txt" file
"""

# %%
# CLI based training approach
"""
    task: detect (perform object detections)
    mode: train (set to learn from the data provided)
    model: yolov8s.t (model architecture to be imported)
    data: <path_to_yaml_file> (path to the yaml file that has data and classes)
    epochs: 100 (minimum of 100, maximum of 300)
    imgsz: 416 (416 x 416 for increased computational efficiency)
    batch: 6 (no of images to be trained at once at a time)
    project: <path_to_training_results>
    name: RT-Traffic-Analytics
"""
# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/RT-Traffic-Analytics-train/data.yaml epochs=100 imgsz=416 batch=64 project=/content/drive/MyDrive/night_img_train name=trafficanalysis-night
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
"""
    Model Stats:
        Model description: Ultralytics YOLOv8.2.67
        Python version: Python-3.10.12
        Torch and CUDA version: torch-2.3.1+cu121
        Device trained on: CUDA:0 (Tesla T4, 15102MiB) - Tesla T4 GPU with 15.835 Gb Memory
        No of layers: 168 layers
        No of parameters: 11,127,519 parameters
        No of gradients to optimize: 11,137,535
        No of GFLOPs - 28.4 (Represents computational complexity - performs 28.4 billion floating-point operations per second)

    Trained Model Stats:
        Generic Performance Evaluation:
            Overall Prediction Accuracy - 0.765
            Recall of bounding boxes - 0.821
        Class Wise Performance Evaluation:
            Precision indicates how many of the detected objects were actually correct.
            Recall indicates how well the model can find the relevant objects in a frame
            <class>: <precision,recall>
            car: <0.91,0.91>
            bus: <0.47,0.75>
            two-wheeler: <0.76,0.78>
            heavy-vehicle: <0.76,0.67>
            auto-rickshaw: <0.91,1.0>

    Model Inference Stats:
        Avg time to preprocess: 0.1ms
        Avg time to inference: 3.2ms
        Avg time to postprocess: 1.1ms
"""

# %%
# Inference using the Trained Model
"""
    task: detect (inference using the model)
    mode: predict
    model: <path_to_weights_file>
    conf: 0.5 (confidence score for prediction)
    source: <path_to_test_image>

"""
# !yolo task=detect mode=predict model=/content/drive/MyDrive/night_img_train/trafficanalysis-night5/weights/best.pt conf=0.5 source=/content/drive/MyDrive/RT-Traffic-Analytics-train/data/raw/243.png
# Out:
# Ultralytics YOLOv8.2.76 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/drive/MyDrive/RT-Traffic-Analytics-train/data/raw/243.png: 256x416 8 cars, 3 buss, 1 two-wheeler, 116.3ms
# Speed: 2.6ms preprocess, 116.3ms inference, 1036.9ms postprocess per image at shape (1, 3, 256, 416)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
